# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
trip = pd.read_csv('trip.csv')
station = pd.read_csv('station.csv')
weather = pd.read_csv('weather.csv')

# %% [markdown]
# ## Exploration

# %%
trip.shape
# Out:
# (669959, 11)

# %%
trip.head()
# Out:
#      id  duration       start_date        start_station_name  \
# 0  4576        63  8/29/2013 14:13  South Van Ness at Market
# 1  4607        70  8/29/2013 14:42        San Jose City Hall
# 2  4130        71  8/29/2013 10:16   Mountain View City Hall
# 3  4251        77  8/29/2013 11:29        San Jose City Hall
# 4  4299        83  8/29/2013 12:02  South Van Ness at Market
#
#    start_station_id         end_date          end_station_name  \
# 0                66  8/29/2013 14:14  South Van Ness at Market
# 1                10  8/29/2013 14:43        San Jose City Hall
# 2                27  8/29/2013 10:17   Mountain View City Hall
# 3                10  8/29/2013 11:30        San Jose City Hall
# 4                66  8/29/2013 12:04            Market at 10th
#
#    end_station_id  bike_id subscription_type zip_code
# 0              66      520        Subscriber    94127
# 1              10      661        Subscriber    95138
# 2              27       48        Subscriber    97214
# 3              10       26        Subscriber    95060
# 4              67      319        Subscriber    94103

# %%
station.head()
# Out:
#    id                               name        lat        long  dock_count  \
# 0   2  San Jose Diridon Caltrain Station  37.329732 -121.901782          27
# 1   3              San Jose Civic Center  37.330698 -121.888979          15
# 2   4             Santa Clara at Almaden  37.333988 -121.894902          11
# 3   5                   Adobe on Almaden  37.331415 -121.893200          19
# 4   6                   San Pedro Square  37.336721 -121.894074          15
#
#        city installation_date
# 0  San Jose          8/6/2013
# 1  San Jose          8/5/2013
# 2  San Jose          8/6/2013
# 3  San Jose          8/5/2013
# 4  San Jose          8/7/2013

# %%
weather.head()
# Out:
#         date  max_temperature_f  mean_temperature_f  min_temperature_f  \
# 0  8/29/2013               74.0                68.0               61.0
# 1  8/30/2013               78.0                69.0               60.0
# 2  8/31/2013               71.0                64.0               57.0
# 3   9/1/2013               74.0                66.0               58.0
# 4   9/2/2013               75.0                69.0               62.0
#
#    max_dew_point_f  mean_dew_point_f  min_dew_point_f  max_humidity  \
# 0             61.0              58.0             56.0          93.0
# 1             61.0              58.0             56.0          90.0
# 2             57.0              56.0             54.0          93.0
# 3             60.0              56.0             53.0          87.0
# 4             61.0              60.0             58.0          93.0
#
#    mean_humidity  min_humidity   ...     mean_visibility_miles  \
# 0           75.0          57.0   ...                      10.0
# 1           70.0          50.0   ...                      10.0
# 2           75.0          57.0   ...                      10.0
# 3           68.0          49.0   ...                      10.0
# 4           77.0          61.0   ...                      10.0
#
#    min_visibility_miles  max_wind_Speed_mph  mean_wind_speed_mph  \
# 0                  10.0                23.0                 11.0
# 1                   7.0                29.0                 13.0
# 2                  10.0                26.0                 15.0
# 3                  10.0                25.0                 13.0
# 4                   6.0                23.0                 12.0
#
#    max_gust_speed_mph  precipitation_inches  cloud_cover  events  \
# 0                28.0                     0          4.0     NaN
# 1                35.0                     0          2.0     NaN
# 2                31.0                     0          4.0     NaN
# 3                29.0                     0          4.0     NaN
# 4                30.0                     0          6.0     NaN
#
#    wind_dir_degrees zip_code
# 0             286.0    94107
# 1             291.0    94107
# 2             284.0    94107
# 3             284.0    94107
# 4             277.0    94107
#
# [5 rows x 24 columns]

# %%
#check if id is unique
result = trip.groupby('id')['start_date'].count().sort_values(ascending = False)
#all equal to 1, is unique
result.head()
# Out:
# id
# 913460    1
# 305542    1
# 305569    1
# 305568    1
# 305567    1
# Name: start_date, dtype: int64

# %% [markdown]
# Check for missing values

# %%
trip.isnull().sum()
# Out:
# id                       0
# duration                 0
# start_date               0
# start_station_name       0
# start_station_id         0
# end_date                 0
# end_station_name         0
# end_station_id           0
# bike_id                  0
# subscription_type        0
# zip_code              6619
# dtype: int64

# %%
weather.isnull().sum()
# Out:
# date                                 0
# max_temperature_f                    4
# mean_temperature_f                   4
# min_temperature_f                    4
# max_dew_point_f                     54
# mean_dew_point_f                    54
# min_dew_point_f                     54
# max_humidity                        54
# mean_humidity                       54
# min_humidity                        54
# max_sea_level_pressure_inches        1
# mean_sea_level_pressure_inches       1
# min_sea_level_pressure_inches        1
# max_visibility_miles                13
# mean_visibility_miles               13
# min_visibility_miles                13
# max_wind_Speed_mph                   1
# mean_wind_speed_mph                  1
# max_gust_speed_mph                 899
# precipitation_inches                 1
# cloud_cover                          1
# events                            3143
# wind_dir_degrees                     1
# zip_code                             0
# dtype: int64

# %% [markdown]
# ## Merge Data

# %%
trip.dtypes
# Out:
# id                     int64
# duration               int64
# start_date            object
# start_station_name    object
# start_station_id       int64
# end_date              object
# end_station_name      object
# end_station_id         int64
# bike_id                int64
# subscription_type     object
# zip_code              object
# dtype: object

# %%
station.dtypes
# Out:
# id                     int64
# name                  object
# lat                  float64
# long                 float64
# dock_count             int64
# city                  object
# installation_date     object
# dtype: object

# %%
weather.dtypes
# Out:
# date                               object
# max_temperature_f                 float64
# mean_temperature_f                float64
# min_temperature_f                 float64
# max_dew_point_f                   float64
# mean_dew_point_f                  float64
# min_dew_point_f                   float64
# max_humidity                      float64
# mean_humidity                     float64
# min_humidity                      float64
# max_sea_level_pressure_inches     float64
# mean_sea_level_pressure_inches    float64
# min_sea_level_pressure_inches     float64
# max_visibility_miles              float64
# mean_visibility_miles             float64
# min_visibility_miles              float64
# max_wind_Speed_mph                float64
# mean_wind_speed_mph               float64
# max_gust_speed_mph                float64
# precipitation_inches               object
# cloud_cover                       float64
# events                             object
# wind_dir_degrees                  float64
# zip_code                            int64
# dtype: object

# %%
###Transform trip data
##Get rid of customer zipcode since it is not realiable and will not be used for analysis
df1 = trip.drop(columns = ['zip_code'])
##Transform start and end date to datetime objects
df1['start_date'] = df1['start_date'].apply(lambda x: datetime.strptime(x, '%m/%d/%Y %H:%M'))
df1['end_date'] = df1['end_date'].apply(lambda x: datetime.strptime(x, '%m/%d/%Y %H:%M'))
##Extracc only y/m/d to join with weather data later on
df1['date_for_join'] = df1['start_date'].apply(lambda x: x.strftime('%Y-%m-%d'))
df1['date_for_join'] = df1['date_for_join'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))

# %%
###Join trip data with station data
##Transform the "city" column into corrsponding zipcode
##As author of the dataset suggests, 94107=San Francisco, 94063=Redwood City, 94301=Palo Alto, 94041=Mountain View, 95113= San Jose
city_zip = pd.DataFrame({'city': ['San Jose', 'Redwood City', 'Mountain View', 'Palo Alto','San Francisco'], \
                         'zip_for_join': [95113,94063,94041,94301,94107]})
merge1 = station.merge(city_zip, how = 'left', left_on = 'city', right_on = 'city')

# %%
merge2 = merge1.copy()
merge2.columns = ['start_station_id','start_name','start_lat','start_long','start_dock_count','start_city','start_installation_date','start_zip']

# %%
merge3 = merge1.copy()
merge3.columns =  ['end_station_id','end_name','end_lat','end_long','end_dock_count','end_city','end_installation_date','end_zip']

# %%
merge4 = df1.merge(merge2, how = 'left', left_on = 'start_station_id',right_on = 'start_station_id')

# %%
merge5 = merge4.merge(merge3,how = 'left', left_on = 'end_station_id',right_on = 'end_station_id' )

# %%
merge6 = merge5.drop(columns = ['start_name','end_name'])

# %%
###Transform Weather data
##Transform date to date object
weather['date'] = weather['date'].apply(lambda x: datetime.strptime(x,'%m/%d/%Y'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-c165b2dc4a97> in <module>
#       1 ###Transform Weather data
#       2 ##Transform date to date object
# ----> 3 weather['date'] = weather['date'].apply(lambda x: datetime.strptime(x,'%m/%d/%Y'))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-45-c165b2dc4a97> in <lambda>(x)
#       1 ###Transform Weather data
#       2 ##Transform date to date object
# ----> 3 weather['date'] = weather['date'].apply(lambda x: datetime.strptime(x,'%m/%d/%Y'))
#
# TypeError: strptime() argument 1 must be str, not Timestamp

# %%
start_weather = weather.copy()
columns = list(start_weather.columns)
new_columns = []
for i in columns:
    i = 'start_' + i
    new_columns.append(i)
start_weather.columns = new_columns

# %%
end_weather = weather.copy()
columns = list(end_weather.columns)
new_columns = []
for i in columns:
    i = 'end_' + i
    new_columns.append(i)
end_weather.columns = new_columns

# %%
merge7 = merge6.merge(start_weather, how = 'left', left_on = ['date_for_join','start_zip'], \
                      right_on = ['start_date','start_zip_code'])

# %%
merge8 = merge7.merge(end_weather,how = 'left', left_on = ['date_for_join','end_zip'], \
                      right_on = ['end_date','end_zip_code'])

# %%
merge8.head(5).transpose()
# Out:
#                                                            0  \
# id                                                      4576
# duration                                                  63
# start_date_x                             2013-08-29 14:13:00
# start_station_name                  South Van Ness at Market
# start_station_id                                          66
# end_date_x                               2013-08-29 14:14:00
# end_station_name                    South Van Ness at Market
# end_station_id                                            66
# bike_id                                                  520
# subscription_type                                 Subscriber
# date_for_join                            2013-08-29 00:00:00
# start_lat                                            37.7748
# start_long                                          -122.419
# start_dock_count                                          19
# start_city                                     San Francisco
# start_installation_date                            8/23/2013
# start_zip                                              94107
# end_lat                                              37.7748
# end_long                                            -122.419
# end_dock_count                                            19
# end_city                                       San Francisco
# end_installation_date                              8/23/2013
# end_zip                                                94107
# start_date_y                             2013-08-29 00:00:00
# start_max_temperature_f                                   74
# start_mean_temperature_f                                  68
# start_min_temperature_f                                   61
# start_max_dew_point_f                                     61
# start_mean_dew_point_f                                    58
# start_min_dew_point_f                                     56
# ...                                                      ...
# start_max_gust_speed_mph                                  28
# start_precipitation_inches                                 0
# start_cloud_cover                                          4
# start_events                                             NaN
# start_wind_dir_degrees                                   286
# start_zip_code                                         94107
# end_date_y                               2013-08-29 00:00:00
# end_max_temperature_f                                     74
# end_mean_temperature_f                                    68
# end_min_temperature_f                                     61
# end_max_dew_point_f                                       61
# end_mean_dew_point_f                                      58
# end_min_dew_point_f                                       56
# end_max_humidity                                          93
# end_mean_humidity                                         75
# end_min_humidity                                          57
# end_max_sea_level_pressure_inches                      30.07
# end_mean_sea_level_pressure_inches                     30.02
# end_min_sea_level_pressure_inches                      29.97
# end_max_visibility_miles                                  10
# end_mean_visibility_miles                                 10
# end_min_visibility_miles                                  10
# end_max_wind_Speed_mph                                    23
# end_mean_wind_speed_mph                                   11
# end_max_gust_speed_mph                                    28
# end_precipitation_inches                                   0
# end_cloud_cover                                            4
# end_events                                               NaN
# end_wind_dir_degrees                                     286
# end_zip_code                                           94107
#
#                                                       1  \
# id                                                 4607
# duration                                             70
# start_date_x                        2013-08-29 14:42:00
# start_station_name                   San Jose City Hall
# start_station_id                                     10
# end_date_x                          2013-08-29 14:43:00
# end_station_name                     San Jose City Hall
# end_station_id                                       10
# bike_id                                             661
# subscription_type                            Subscriber
# date_for_join                       2013-08-29 00:00:00
# start_lat                                       37.3374
# start_long                                     -121.887
# start_dock_count                                     15
# start_city                                     San Jose
# start_installation_date                        8/6/2013
# start_zip                                         95113
# end_lat                                         37.3374
# end_long                                       -121.887
# end_dock_count                                       15
# end_city                                       San Jose
# end_installation_date                          8/6/2013
# end_zip                                           95113
# start_date_y                        2013-08-29 00:00:00
# start_max_temperature_f                              81
# start_mean_temperature_f                             72
# start_min_temperature_f                              63
# start_max_dew_point_f                                62
# start_mean_dew_point_f                               61
# start_min_dew_point_f                                59
# ...                                                 ...
# start_max_gust_speed_mph                             24
# start_precipitation_inches                            0
# start_cloud_cover                                     4
# start_events                                        NaN
# start_wind_dir_degrees                              320
# start_zip_code                                    95113
# end_date_y                          2013-08-29 00:00:00
# end_max_temperature_f                                81
# end_mean_temperature_f                               72
# end_min_temperature_f                                63
# end_max_dew_point_f                                  62
# end_mean_dew_point_f                                 61
# end_min_dew_point_f                                  59
# end_max_humidity                                     87
# end_mean_humidity                                    69
# end_min_humidity                                     51
# end_max_sea_level_pressure_inches                 30.06
# end_mean_sea_level_pressure_inches                30.02
# end_min_sea_level_pressure_inches                 29.96
# end_max_visibility_miles                             10
# end_mean_visibility_miles                            10
# end_min_visibility_miles                             10
# end_max_wind_Speed_mph                               16
# end_mean_wind_speed_mph                               7
# end_max_gust_speed_mph                               24
# end_precipitation_inches                              0
# end_cloud_cover                                       4
# end_events                                          NaN
# end_wind_dir_degrees                                320
# end_zip_code                                      95113
#
#                                                           2  \
# id                                                     4130
# duration                                                 71
# start_date_x                            2013-08-29 10:16:00
# start_station_name                  Mountain View City Hall
# start_station_id                                         27
# end_date_x                              2013-08-29 10:17:00
# end_station_name                    Mountain View City Hall
# end_station_id                                           27
# bike_id                                                  48
# subscription_type                                Subscriber
# date_for_join                           2013-08-29 00:00:00
# start_lat                                           37.3892
# start_long                                         -122.082
# start_dock_count                                         15
# start_city                                    Mountain View
# start_installation_date                           8/16/2013
# start_zip                                             94041
# end_lat                                             37.3892
# end_long                                           -122.082
# end_dock_count                                           15
# end_city                                      Mountain View
# end_installation_date                             8/16/2013
# end_zip                                               94041
# start_date_y                            2013-08-29 00:00:00
# start_max_temperature_f                                  80
# start_mean_temperature_f                                 70
# start_min_temperature_f                                  64
# start_max_dew_point_f                                    65
# start_mean_dew_point_f                                   61
# start_min_dew_point_f                                    58
# ...                                                     ...
# start_max_gust_speed_mph                                 16
# start_precipitation_inches                                0
# start_cloud_cover                                         4
# start_events                                            NaN
# start_wind_dir_degrees                                  355
# start_zip_code                                        94041
# end_date_y                              2013-08-29 00:00:00
# end_max_temperature_f                                    80
# end_mean_temperature_f                                   70
# end_min_temperature_f                                    64
# end_max_dew_point_f                                      65
# end_mean_dew_point_f                                     61
# end_min_dew_point_f                                      58
# end_max_humidity                                         83
# end_mean_humidity                                        72
# end_min_humidity                                         55
# end_max_sea_level_pressure_inches                     30.04
# end_mean_sea_level_pressure_inches                    30.04
# end_min_sea_level_pressure_inches                     29.94
# end_max_visibility_miles                                 10
# end_mean_visibility_miles                                10
# end_min_visibility_miles                                 10
# end_max_wind_Speed_mph                                   16
# end_mean_wind_speed_mph                                   5
# end_max_gust_speed_mph                                   16
# end_precipitation_inches                                  0
# end_cloud_cover                                           4
# end_events                                              NaN
# end_wind_dir_degrees                                    355
# end_zip_code                                          94041
#
#                                                       3  \
# id                                                 4251
# duration                                             77
# start_date_x                        2013-08-29 11:29:00
# start_station_name                   San Jose City Hall
# start_station_id                                     10
# end_date_x                          2013-08-29 11:30:00
# end_station_name                     San Jose City Hall
# end_station_id                                       10
# bike_id                                              26
# subscription_type                            Subscriber
# date_for_join                       2013-08-29 00:00:00
# start_lat                                       37.3374
# start_long                                     -121.887
# start_dock_count                                     15
# start_city                                     San Jose
# start_installation_date                        8/6/2013
# start_zip                                         95113
# end_lat                                         37.3374
# end_long                                       -121.887
# end_dock_count                                       15
# end_city                                       San Jose
# end_installation_date                          8/6/2013
# end_zip                                           95113
# start_date_y                        2013-08-29 00:00:00
# start_max_temperature_f                              81
# start_mean_temperature_f                             72
# start_min_temperature_f                              63
# start_max_dew_point_f                                62
# start_mean_dew_point_f                               61
# start_min_dew_point_f                                59
# ...                                                 ...
# start_max_gust_speed_mph                             24
# start_precipitation_inches                            0
# start_cloud_cover                                     4
# start_events                                        NaN
# start_wind_dir_degrees                              320
# start_zip_code                                    95113
# end_date_y                          2013-08-29 00:00:00
# end_max_temperature_f                                81
# end_mean_temperature_f                               72
# end_min_temperature_f                                63
# end_max_dew_point_f                                  62
# end_mean_dew_point_f                                 61
# end_min_dew_point_f                                  59
# end_max_humidity                                     87
# end_mean_humidity                                    69
# end_min_humidity                                     51
# end_max_sea_level_pressure_inches                 30.06
# end_mean_sea_level_pressure_inches                30.02
# end_min_sea_level_pressure_inches                 29.96
# end_max_visibility_miles                             10
# end_mean_visibility_miles                            10
# end_min_visibility_miles                             10
# end_max_wind_Speed_mph                               16
# end_mean_wind_speed_mph                               7
# end_max_gust_speed_mph                               24
# end_precipitation_inches                              0
# end_cloud_cover                                       4
# end_events                                          NaN
# end_wind_dir_degrees                                320
# end_zip_code                                      95113
#
#                                                            4
# id                                                      4299
# duration                                                  83
# start_date_x                             2013-08-29 12:02:00
# start_station_name                  South Van Ness at Market
# start_station_id                                          66
# end_date_x                               2013-08-29 12:04:00
# end_station_name                              Market at 10th
# end_station_id                                            67
# bike_id                                                  319
# subscription_type                                 Subscriber
# date_for_join                            2013-08-29 00:00:00
# start_lat                                            37.7748
# start_long                                          -122.419
# start_dock_count                                          19
# start_city                                     San Francisco
# start_installation_date                            8/23/2013
# start_zip                                              94107
# end_lat                                              37.7766
# end_long                                            -122.417
# end_dock_count                                            27
# end_city                                       San Francisco
# end_installation_date                              8/23/2013
# end_zip                                                94107
# start_date_y                             2013-08-29 00:00:00
# start_max_temperature_f                                   74
# start_mean_temperature_f                                  68
# start_min_temperature_f                                   61
# start_max_dew_point_f                                     61
# start_mean_dew_point_f                                    58
# start_min_dew_point_f                                     56
# ...                                                      ...
# start_max_gust_speed_mph                                  28
# start_precipitation_inches                                 0
# start_cloud_cover                                          4
# start_events                                             NaN
# start_wind_dir_degrees                                   286
# start_zip_code                                         94107
# end_date_y                               2013-08-29 00:00:00
# end_max_temperature_f                                     74
# end_mean_temperature_f                                    68
# end_min_temperature_f                                     61
# end_max_dew_point_f                                       61
# end_mean_dew_point_f                                      58
# end_min_dew_point_f                                       56
# end_max_humidity                                          93
# end_mean_humidity                                         75
# end_min_humidity                                          57
# end_max_sea_level_pressure_inches                      30.07
# end_mean_sea_level_pressure_inches                     30.02
# end_min_sea_level_pressure_inches                      29.97
# end_max_visibility_miles                                  10
# end_mean_visibility_miles                                 10
# end_min_visibility_miles                                  10
# end_max_wind_Speed_mph                                    23
# end_mean_wind_speed_mph                                   11
# end_max_gust_speed_mph                                    28
# end_precipitation_inches                                   0
# end_cloud_cover                                            4
# end_events                                               NaN
# end_wind_dir_degrees                                     286
# end_zip_code                                           94107
#
# [71 rows x 5 columns]

# %%
merge9 = merge8.drop(columns = ['end_zip_code','end_date_y','start_date_y',\
                                'start_zip_code','date_for_join'])
merge9.rename(columns={'start_date_x':'start_date','end_date_x':'end_date'}, inplace=True)

# %% [markdown]
# ## Clean merged sets

# %%
merge9.shape
# Out:
# (669959, 66)

# %%
na_list = pd.DataFrame(merge9.isnull().sum())
na_list['column_name'] = na_list.index
na_list.columns = ['count_na','column_name']
na_column = na_list[na_list['count_na']>0]

# %%
na_column.sort_values(by = 'count_na')
# Out:
#                                       count_na  \
# start_wind_dir_degrees                      14
# end_precipitation_inches                    14
# end_mean_wind_speed_mph                     14
# end_max_wind_Speed_mph                      14
# end_min_sea_level_pressure_inches           14
# end_mean_sea_level_pressure_inches          14
# end_max_sea_level_pressure_inches           14
# end_cloud_cover                             14
# start_cloud_cover                           14
# start_precipitation_inches                  14
# start_mean_wind_speed_mph                   14
# start_max_wind_Speed_mph                    14
# end_wind_dir_degrees                        14
# start_min_sea_level_pressure_inches         14
# start_mean_sea_level_pressure_inches        14
# start_max_sea_level_pressure_inches         14
# start_max_temperature_f                     66
# start_mean_temperature_f                    66
# start_min_temperature_f                     66
# end_max_temperature_f                       66
# end_mean_temperature_f                      66
# end_min_temperature_f                       66
# start_max_visibility_miles                 153
# start_mean_visibility_miles                153
# start_min_visibility_miles                 153
# end_max_visibility_miles                   154
# end_mean_visibility_miles                  154
# end_min_visibility_miles                   154
# start_mean_humidity                        353
# start_max_humidity                         353
# start_min_dew_point_f                      353
# start_mean_dew_point_f                     353
# start_max_dew_point_f                      353
# start_min_humidity                         353
# end_mean_dew_point_f                       363
# end_min_dew_point_f                        363
# end_mean_humidity                          363
# end_min_humidity                           363
# end_max_dew_point_f                        363
# end_max_humidity                           363
#
#                                                                column_name
# start_wind_dir_degrees                              start_wind_dir_degrees
# end_precipitation_inches                          end_precipitation_inches
# end_mean_wind_speed_mph                            end_mean_wind_speed_mph
# end_max_wind_Speed_mph                              end_max_wind_Speed_mph
# end_min_sea_level_pressure_inches        end_min_sea_level_pressure_inches
# end_mean_sea_level_pressure_inches      end_mean_sea_level_pressure_inches
# end_max_sea_level_pressure_inches        end_max_sea_level_pressure_inches
# end_cloud_cover                                            end_cloud_cover
# start_cloud_cover                                        start_cloud_cover
# start_precipitation_inches                      start_precipitation_inches
# start_mean_wind_speed_mph                        start_mean_wind_speed_mph
# start_max_wind_Speed_mph                          start_max_wind_Speed_mph
# end_wind_dir_degrees                                  end_wind_dir_degrees
# start_min_sea_level_pressure_inches    start_min_sea_level_pressure_inches
# start_mean_sea_level_pressure_inches  start_mean_sea_level_pressure_inches
# start_max_sea_level_pressure_inches    start_max_sea_level_pressure_inches
# start_max_temperature_f                            start_max_temperature_f
# start_mean_temperature_f                          start_mean_temperature_f
# start_min_temperature_f                            start_min_temperature_f
# end_max_temperature_f                                end_max_temperature_f
# end_mean_temperature_f                              end_mean_temperature_f
# end_min_temperature_f                                end_min_temperature_f
# start_max_visibility_miles                      start_max_visibility_miles
# start_mean_visibility_miles                    start_mean_visibility_miles
# start_min_visibility_miles                      start_min_visibility_miles
# end_max_visibility_miles                          end_max_visibility_miles
# end_mean_visibility_miles                        end_mean_visibility_miles
# end_min_visibility_miles                          end_min_visibility_miles
# start_mean_humidity                                    start_mean_humidity
# start_max_humidity                                      start_max_humidity
# start_min_dew_point_f                                start_min_dew_point_f
# start_mean_dew_point_f                              start_mean_dew_point_f
# start_max_dew_point_f                                start_max_dew_point_f
# start_min_humidity                                      start_min_humidity
# end_mean_dew_point_f                                  end_mean_dew_point_f
# end_min_dew_point_f                                    end_min_dew_point_f
# end_mean_humidity                                        end_mean_humidity
# end_min_humidity                                          end_min_humidity
# end_max_dew_point_f                                    end_max_dew_point_f
# end_max_humidity                                          end_max_humidity

# %%
merge9['start_events'] = merge9['start_events'].fillna('no special events')

# %%
merge9['end_events'] = merge9['end_events'].fillna('no special events')

# %%
merge9 = merge9.drop(columns = ['start_max_gust_speed_mph','end_max_gust_speed_mph'])

# %%
## Removing 0.07% of records that has missing values
merge10 = merge9.dropna()

# %%
merge10.shape
# Out:
# (669431, 64)

# %%
merge10.to_csv('SF_Bay_Area_Bike_Share_Data_Cleaned.csv', index = False)
