# %%
import pandas as pd
import numpy as np

# %%
states = pd.read_csv('states.csv')
naep = pd.read_csv('naep.csv')
districts = pd.read_csv('districts.csv')

# %%
states.columns
# Out:
# Index(['STATE', 'YEAR', 'ENROLL', 'TOTAL_REVENUE', 'FEDERAL_REVENUE',
#        'STATE_REVENUE', 'LOCAL_REVENUE', 'TOTAL_EXPENDITURE',
#        'INSTRUCTION_EXPENDITURE', 'SUPPORT_SERVICES_EXPENDITURE',
#        'OTHER_EXPENDITURE', 'CAPITAL_OUTLAY_EXPENDITURE'],
#       dtype='object')

# %%
naep.columns
# Out:
# Index(['YEAR', 'STATE', 'AVG_SCORE', 'TEST_SUBJECT', 'TEST_YEAR'], dtype='object')

# %%
districts.columns
# Out:
# Index(['STATE', 'ENROLL', 'NAME', 'YRDATA', 'TOTALREV', 'TFEDREV', 'TSTREV',
#        'TLOCREV', 'TOTALEXP', 'TCURINST', 'TCURSSVC', 'TCURONON', 'TCAPOUT'],
#       dtype='object')

# %%
districts.shape
# Out:
# (374161, 13)

# %%
districts.isnull().sum()
# Out:
# STATE           0
# ENROLL      15868
# NAME            0
# YRDATA          0
# TOTALREV        0
# TFEDREV         0
# TSTREV          0
# TLOCREV         0
# TOTALEXP        0
# TCURINST        0
# TCURSSVC        0
# TCURONON    15868
# TCAPOUT         0
# dtype: int64

# %%
##The author mentioned that there is no enrollment data for year 1992
enroll92 = districts[districts['YRDATA']== 1992]

# %%
##The length of 1992 district matches the number of Na
len(enroll92)
# Out:
# 15868

# %%
## Consider excluding 1992 data. Since it's the first year, excluding 1992 will not create a "hole" in data
districts['YRDATA'].min()
# Out:
# 1992

# %%
## Excluding 1992
df1 = districts[districts['YRDATA']>1992]

# %%
df1.isnull().sum()
# Out:
# STATE       0
# ENROLL      0
# NAME        0
# YRDATA      0
# TOTALREV    0
# TFEDREV     0
# TSTREV      0
# TLOCREV     0
# TOTALEXP    0
# TCURINST    0
# TCURSSVC    0
# TCURONON    0
# TCAPOUT     0
# dtype: int64

# %%
## Joining districts with states
states.isnull().sum()
# Out:
# STATE                            0
# YEAR                             0
# ENROLL                          51
# TOTAL_REVENUE                    0
# FEDERAL_REVENUE                  0
# STATE_REVENUE                    0
# LOCAL_REVENUE                    0
# TOTAL_EXPENDITURE                0
# INSTRUCTION_EXPENDITURE          0
# SUPPORT_SERVICES_EXPENDITURE     0
# OTHER_EXPENDITURE               51
# CAPITAL_OUTLAY_EXPENDITURE       0
# dtype: int64

# %%
## Exclude 1992
df2 = states[states['YEAR']>1992]

# %%
merge1 = df1.merge(df2, how = 'left', left_on = ['STATE','YRDATA'], right_on = ['STATE','YEAR'])

# %%
merge1.head(5).transpose()
# Out:
#                                                            0  \
# STATE                                                Alabama
# ENROLL_x                                                9609
# NAME                          AUTAUGA COUNTY SCHOOL DISTRICT
# YRDATA                                                  2016
# TOTALREV                                               80867
# TFEDREV                                                 7447
# TSTREV                                                 53842
# TLOCREV                                                19578
# TOTALEXP                                               76672
# TCURINST                                               43843
# TCURSSVC                                               23941
# TCURONON                                                6401
# TCAPOUT                                                 1506
# YEAR                                                    2016
# ENROLL_y                                              734652
# TOTAL_REVENUE                                        7498567
# FEDERAL_REVENUE                                       797631
# STATE_REVENUE                                        4097696
# LOCAL_REVENUE                                        2603240
# TOTAL_EXPENDITURE                                    7708845
# INSTRUCTION_EXPENDITURE                              3865453
# SUPPORT_SERVICES_EXPENDITURE                         2439634
# OTHER_EXPENDITURE                                     602452
# CAPITAL_OUTLAY_EXPENDITURE                            610743
#
#                                                            1  \
# STATE                                                Alabama
# ENROLL_x                                               30931
# NAME                          BALDWIN COUNTY SCHOOL DISTRICT
# YRDATA                                                  2016
# TOTALREV                                              338236
# TFEDREV                                                23710
# TSTREV                                                145180
# TLOCREV                                               169346
# TOTALEXP                                              299880
# TCURINST                                              164977
# TCURSSVC                                               97231
# TCURONON                                               19439
# TCAPOUT                                                 9749
# YEAR                                                    2016
# ENROLL_y                                              734652
# TOTAL_REVENUE                                        7498567
# FEDERAL_REVENUE                                       797631
# STATE_REVENUE                                        4097696
# LOCAL_REVENUE                                        2603240
# TOTAL_EXPENDITURE                                    7708845
# INSTRUCTION_EXPENDITURE                              3865453
# SUPPORT_SERVICES_EXPENDITURE                         2439634
# OTHER_EXPENDITURE                                     602452
# CAPITAL_OUTLAY_EXPENDITURE                            610743
#
#                                                            2  \
# STATE                                                Alabama
# ENROLL_x                                                 912
# NAME                          BARBOUR COUNTY SCHOOL DISTRICT
# YRDATA                                                  2016
# TOTALREV                                               10116
# TFEDREV                                                 2342
# TSTREV                                                  5434
# TLOCREV                                                 2340
# TOTALEXP                                               10070
# TCURINST                                                4907
# TCURSSVC                                                3896
# TCURONON                                                 975
# TCAPOUT                                                  110
# YEAR                                                    2016
# ENROLL_y                                              734652
# TOTAL_REVENUE                                        7498567
# FEDERAL_REVENUE                                       797631
# STATE_REVENUE                                        4097696
# LOCAL_REVENUE                                        2603240
# TOTAL_EXPENDITURE                                    7708845
# INSTRUCTION_EXPENDITURE                              3865453
# SUPPORT_SERVICES_EXPENDITURE                         2439634
# OTHER_EXPENDITURE                                     602452
# CAPITAL_OUTLAY_EXPENDITURE                            610743
#
#                                                          3  \
# STATE                                              Alabama
# ENROLL_x                                              2842
# NAME                          EUFAULA CITY SCHOOL DISTRICT
# YRDATA                                                2016
# TOTALREV                                             26182
# TFEDREV                                               3558
# TSTREV                                               15900
# TLOCREV                                               6724
# TOTALEXP                                             29843
# TCURINST                                             15302
# TCURSSVC                                              7901
# TCURONON                                              2274
# TCAPOUT                                               4133
# YEAR                                                  2016
# ENROLL_y                                            734652
# TOTAL_REVENUE                                      7498567
# FEDERAL_REVENUE                                     797631
# STATE_REVENUE                                      4097696
# LOCAL_REVENUE                                      2603240
# TOTAL_EXPENDITURE                                  7708845
# INSTRUCTION_EXPENDITURE                            3865453
# SUPPORT_SERVICES_EXPENDITURE                       2439634
# OTHER_EXPENDITURE                                   602452
# CAPITAL_OUTLAY_EXPENDITURE                          610743
#
#                                                         4
# STATE                                             Alabama
# ENROLL_x                                             3322
# NAME                          BIBB COUNTY SCHOOL DISTRICT
# YRDATA                                               2016
# TOTALREV                                            32486
# TFEDREV                                              3664
# TSTREV                                              21846
# TLOCREV                                              6976
# TOTALEXP                                            31662
# TCURINST                                            16407
# TCURSSVC                                            11087
# TCURONON                                             3122
# TCAPOUT                                               486
# YEAR                                                 2016
# ENROLL_y                                           734652
# TOTAL_REVENUE                                     7498567
# FEDERAL_REVENUE                                    797631
# STATE_REVENUE                                     4097696
# LOCAL_REVENUE                                     2603240
# TOTAL_EXPENDITURE                                 7708845
# INSTRUCTION_EXPENDITURE                           3865453
# SUPPORT_SERVICES_EXPENDITURE                      2439634
# OTHER_EXPENDITURE                                  602452
# CAPITAL_OUTLAY_EXPENDITURE                         610743

# %%
merge1.isnull().sum()
# Out:
# STATE                           0
# ENROLL_x                        0
# NAME                            0
# YRDATA                          0
# TOTALREV                        0
# TFEDREV                         0
# TSTREV                          0
# TLOCREV                         0
# TOTALEXP                        0
# TCURINST                        0
# TCURSSVC                        0
# TCURONON                        0
# TCAPOUT                         0
# YEAR                            0
# ENROLL_y                        0
# TOTAL_REVENUE                   0
# FEDERAL_REVENUE                 0
# STATE_REVENUE                   0
# LOCAL_REVENUE                   0
# TOTAL_EXPENDITURE               0
# INSTRUCTION_EXPENDITURE         0
# SUPPORT_SERVICES_EXPENDITURE    0
# OTHER_EXPENDITURE               0
# CAPITAL_OUTLAY_EXPENDITURE      0
# dtype: int64

# %%
## Joining NAEP data
naep.shape
# Out:
# (2305, 5)

# %%
naep.isnull().sum()
# Out:
# YEAR            0
# STATE           0
# AVG_SCORE       0
# TEST_SUBJECT    0
# TEST_YEAR       0
# dtype: int64

# %%
naep['YEAR'].unique()
# Out:
# array([2017, 2015, 2013, 2011, 2009, 2007, 2005, 2003, 2000, 1996, 1992,
#        1990, 2002, 1998, 1994], dtype=int64)

# %%
unique = pd.DataFrame(naep.groupby(['YEAR','STATE'])['AVG_SCORE'].count())

# %%
unique.head()
# Out:
#                  AVG_SCORE
# YEAR STATE
# 1990 Alabama             1
#      Alaska              1
#      Arizona             1
#      Arkansas            1
#      California          1

# %%
unique.sort_values(by = 'AVG_SCORE',ascending = False)
# Out:
#                            AVG_SCORE
# YEAR STATE
# 2003 Nebraska                      4
# 2009 Arkansas                      4
# 2007 Vermont                       4
#      Virginia                      4
#      Washington                    4
#      West Virginia                 4
#      Wisconsin                     4
#      Wyoming                       4
# 2009 Alabama                       4
#      Alaska                        4
#      Arizona                       4
#      California                    4
# 2007 Texas                         4
# 2009 Colorado                      4
#      Connecticut                   4
#      Delaware                      4
#      District of Columbia          4
#      Florida                       4
#      Georgia                       4
#      Hawaii                        4
#      Idaho                         4
#      Illinois                      4
# 2007 Utah                          4
#      Tennessee                     4
# 2009 Iowa                          4
# 2007 New Jersey                    4
#      Massachusetts                 4
#      Michigan                      4
#      Minnesota                     4
#      Mississippi                   4
# ...                              ...
# 1994 Nebraska                      1
# 2015 DoDEA                         1
# 1994 Hawaii                        1
# 2002 DoDEA                         1
# 1994 Alabama                       1
#      Alaska                        1
#      Arizona                       1
#      Arkansas                      1
#      California                    1
#      Colorado                      1
#      Connecticut                   1
#      Delaware                      1
#      District of Columbia          1
#      Florida                       1
#      Georgia                       1
#      Idaho                         1
#      Montana                       1
#      Illinois                      1
#      Iowa                          1
#      Kansas                        1
#      Kentucky                      1
#      Louisiana                     1
#      Maine                         1
#      Maryland                      1
#      Massachusetts                 1
#      Michigan                      1
#      Minnesota                     1
#      Mississippi                   1
#      Missouri                      1
# 1990 Alabama                       1
#
# [775 rows x 1 columns]

# %%
df3 = naep[naep['YEAR']>1992]

# %%
merge2 = merge1.merge(df3,how = 'left', left_on = ['STATE','YEAR'],right_on = ['STATE','YEAR'])

# %%
merge2.head(5).transpose()
# Out:
#                                                            0  \
# STATE                                                Alabama
# ENROLL_x                                                9609
# NAME                          AUTAUGA COUNTY SCHOOL DISTRICT
# YRDATA                                                  2016
# TOTALREV                                               80867
# TFEDREV                                                 7447
# TSTREV                                                 53842
# TLOCREV                                                19578
# TOTALEXP                                               76672
# TCURINST                                               43843
# TCURSSVC                                               23941
# TCURONON                                                6401
# TCAPOUT                                                 1506
# YEAR                                                    2016
# ENROLL_y                                              734652
# TOTAL_REVENUE                                        7498567
# FEDERAL_REVENUE                                       797631
# STATE_REVENUE                                        4097696
# LOCAL_REVENUE                                        2603240
# TOTAL_EXPENDITURE                                    7708845
# INSTRUCTION_EXPENDITURE                              3865453
# SUPPORT_SERVICES_EXPENDITURE                         2439634
# OTHER_EXPENDITURE                                     602452
# CAPITAL_OUTLAY_EXPENDITURE                            610743
# AVG_SCORE                                                NaN
# TEST_SUBJECT                                             NaN
# TEST_YEAR                                                NaN
#
#                                                            1  \
# STATE                                                Alabama
# ENROLL_x                                               30931
# NAME                          BALDWIN COUNTY SCHOOL DISTRICT
# YRDATA                                                  2016
# TOTALREV                                              338236
# TFEDREV                                                23710
# TSTREV                                                145180
# TLOCREV                                               169346
# TOTALEXP                                              299880
# TCURINST                                              164977
# TCURSSVC                                               97231
# TCURONON                                               19439
# TCAPOUT                                                 9749
# YEAR                                                    2016
# ENROLL_y                                              734652
# TOTAL_REVENUE                                        7498567
# FEDERAL_REVENUE                                       797631
# STATE_REVENUE                                        4097696
# LOCAL_REVENUE                                        2603240
# TOTAL_EXPENDITURE                                    7708845
# INSTRUCTION_EXPENDITURE                              3865453
# SUPPORT_SERVICES_EXPENDITURE                         2439634
# OTHER_EXPENDITURE                                     602452
# CAPITAL_OUTLAY_EXPENDITURE                            610743
# AVG_SCORE                                                NaN
# TEST_SUBJECT                                             NaN
# TEST_YEAR                                                NaN
#
#                                                            2  \
# STATE                                                Alabama
# ENROLL_x                                                 912
# NAME                          BARBOUR COUNTY SCHOOL DISTRICT
# YRDATA                                                  2016
# TOTALREV                                               10116
# TFEDREV                                                 2342
# TSTREV                                                  5434
# TLOCREV                                                 2340
# TOTALEXP                                               10070
# TCURINST                                                4907
# TCURSSVC                                                3896
# TCURONON                                                 975
# TCAPOUT                                                  110
# YEAR                                                    2016
# ENROLL_y                                              734652
# TOTAL_REVENUE                                        7498567
# FEDERAL_REVENUE                                       797631
# STATE_REVENUE                                        4097696
# LOCAL_REVENUE                                        2603240
# TOTAL_EXPENDITURE                                    7708845
# INSTRUCTION_EXPENDITURE                              3865453
# SUPPORT_SERVICES_EXPENDITURE                         2439634
# OTHER_EXPENDITURE                                     602452
# CAPITAL_OUTLAY_EXPENDITURE                            610743
# AVG_SCORE                                                NaN
# TEST_SUBJECT                                             NaN
# TEST_YEAR                                                NaN
#
#                                                          3  \
# STATE                                              Alabama
# ENROLL_x                                              2842
# NAME                          EUFAULA CITY SCHOOL DISTRICT
# YRDATA                                                2016
# TOTALREV                                             26182
# TFEDREV                                               3558
# TSTREV                                               15900
# TLOCREV                                               6724
# TOTALEXP                                             29843
# TCURINST                                             15302
# TCURSSVC                                              7901
# TCURONON                                              2274
# TCAPOUT                                               4133
# YEAR                                                  2016
# ENROLL_y                                            734652
# TOTAL_REVENUE                                      7498567
# FEDERAL_REVENUE                                     797631
# STATE_REVENUE                                      4097696
# LOCAL_REVENUE                                      2603240
# TOTAL_EXPENDITURE                                  7708845
# INSTRUCTION_EXPENDITURE                            3865453
# SUPPORT_SERVICES_EXPENDITURE                       2439634
# OTHER_EXPENDITURE                                   602452
# CAPITAL_OUTLAY_EXPENDITURE                          610743
# AVG_SCORE                                              NaN
# TEST_SUBJECT                                           NaN
# TEST_YEAR                                              NaN
#
#                                                         4
# STATE                                             Alabama
# ENROLL_x                                             3322
# NAME                          BIBB COUNTY SCHOOL DISTRICT
# YRDATA                                               2016
# TOTALREV                                            32486
# TFEDREV                                              3664
# TSTREV                                              21846
# TLOCREV                                              6976
# TOTALEXP                                            31662
# TCURINST                                            16407
# TCURSSVC                                            11087
# TCURONON                                             3122
# TCAPOUT                                               486
# YEAR                                                 2016
# ENROLL_y                                           734652
# TOTAL_REVENUE                                     7498567
# FEDERAL_REVENUE                                    797631
# STATE_REVENUE                                     4097696
# LOCAL_REVENUE                                     2603240
# TOTAL_EXPENDITURE                                 7708845
# INSTRUCTION_EXPENDITURE                           3865453
# SUPPORT_SERVICES_EXPENDITURE                      2439634
# OTHER_EXPENDITURE                                  602452
# CAPITAL_OUTLAY_EXPENDITURE                         610743
# AVG_SCORE                                             NaN
# TEST_SUBJECT                                          NaN
# TEST_YEAR                                             NaN

# %%
df_fin = merge2.rename(columns={'ENROLL_x':'District_Enrollment','ENROLL_y':'State_Enrollment'}).drop(columns = ['YRDATA'])

# %%
df_fin.columns
# Out:
# Index(['STATE', 'District_Enrollment', 'NAME', 'TOTALREV', 'TFEDREV', 'TSTREV',
#        'TLOCREV', 'TOTALEXP', 'TCURINST', 'TCURSSVC', 'TCURONON', 'TCAPOUT',
#        'YEAR', 'State_Enrollment', 'TOTAL_REVENUE', 'FEDERAL_REVENUE',
#        'STATE_REVENUE', 'LOCAL_REVENUE', 'TOTAL_EXPENDITURE',
#        'INSTRUCTION_EXPENDITURE', 'SUPPORT_SERVICES_EXPENDITURE',
#        'OTHER_EXPENDITURE', 'CAPITAL_OUTLAY_EXPENDITURE', 'AVG_SCORE',
#        'TEST_SUBJECT', 'TEST_YEAR'],
#       dtype='object')
